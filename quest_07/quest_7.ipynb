# %% [markdown]
# # 딥러닝 프로젝트

# %% [markdown]
# ## 1. Boston 주택 가격 예측 모델

# %%
# 라이브러리 불러오기
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# keras.datasets 안에 boston_housing 데이터셋을 로드합니다.
from keras.datasets import boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# 데이터셋의 크기를 확인합니다.
print(len(train_data))
print(len(test_data))
# Out:
# 404
# 102

# %%
# 문제 1-1: 데이터셋의 전처리를 위해 표준화 작업을 수행합니다.
# 먼저 입력 데이터의 각 특성의 평균을 뺍니다.
mean = train_data.mean(axis=0)
train_data = train_data - mean

# 평균을 뺀 입력 데이터에서 표준편차를 나눕니다.
# 데이터 특성의 중앙이 0에 가깝게 만들고, 표준편차가 1이 되게 만듭니다.
std = train_data.std(axis=0)
train_data = train_data/std

# 테스트 데이터셋도 마찬가지로 평균을 빼고, 표준편차로 나눕니다.
test_data = test_data - mean
test_data = test_data / std

# %%
# train 데이터, 검증 데이터 분리
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.25, random_state = 123)

# %%
# 문제 1-2: 주택 가격 예측을 위한 딥러닝 모델 구성 및 컴파일합니다.
# input_shape은 (train_data.shape[1], )으로 구성합니다.
# 회귀(예측)을 위한 모델이므로 loss를 mse, metrics를 mae로 사용합니다.
model = models.Sequential()
model.add(layers.Input(shape = (train_data.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))
model.summary()

model.compile(loss='mse',
              optimizer='Adam',
              metrics=['mae'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                896
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 문제 1-3: 예측을 위한 딥러닝 모델을 학습합니다.
history = model.fit(train_data, train_labels,
                    epochs=60,
                    batch_size=16,
                    validation_data=(val_data, val_labels))
# Out:
# Epoch 1/60
# 19/19 [==============================] - 1s 10ms/step - loss: 558.0687 - mae: 21.7441 - val_loss: 515.3480 - val_mae: 21.1214
# Epoch 2/60
# 19/19 [==============================] - 0s 3ms/step - loss: 477.9570 - mae: 19.9896 - val_loss: 415.6538 - val_mae: 18.8258
# Epoch 3/60
# 19/19 [==============================] - 0s 3ms/step - loss: 356.6309 - mae: 16.9736 - val_loss: 271.4326 - val_mae: 14.8265
# Epoch 4/60
# 19/19 [==============================] - 0s 3ms/step - loss: 206.4287 - mae: 12.0228 - val_loss: 123.2319 - val_mae: 8.8422
# Epoch 5/60
# 19/19 [==============================] - 0s 3ms/step - loss: 96.2401 - mae: 7.4362 - val_loss: 59.7876 - val_mae: 5.9814
# Epoch 6/60
# 19/19 [==============================] - 0s 3ms/step - loss: 57.6380 - mae: 5.6341 - val_loss: 40.8750 - val_mae: 4.9100
# Epoch 7/60
# 19/19 [==============================] - 0s 3ms/step - loss: 41.4653 - mae: 4.8131 - val_loss: 29.3428 - val_mae: 4.1345
# Epoch 8/60
# 19/19 [==============================] - 0s 3ms/step - loss: 31.6062 - mae: 4.1014 - val_loss: 24.0000 - val_mae: 3.6596
# Epoch 9/60
# 19/19 [==============================] - 0s 3ms/step - loss: 26.5854 - mae: 3.7127 - val_loss: 21.6343 - val_mae: 3.4948
# Epoch 10/60
# 19/19 [==============================] - 0s 3ms/step - loss: 23.7401 - mae: 3.5026 - val_loss: 20.1592 - val_mae: 3.3955
# Epoch 11/60
# 19/19 [==============================] - 0s 3ms/step - loss: 21.9697 - mae: 3.3311 - val_loss: 19.1420 - val_mae: 3.3414
# Epoch 12/60
# 19/19 [==============================] - 0s 3ms/step - loss: 20.5466 - mae: 3.1940 - val_loss: 18.5645 - val_mae: 3.3147
# Epoch 13/60
# 19/19 [==============================] - 0s 4ms/step - loss: 19.2332 - mae: 3.0959 - val_loss: 17.7987 - val_mae: 3.2582
# Epoch 14/60
# 19/19 [==============================] - 0s 3ms/step - loss: 18.3647 - mae: 3.0499 - val_loss: 17.0276 - val_mae: 3.1816
# Epoch 15/60
# 19/19 [==============================] - 0s 3ms/step - loss: 17.3320 - mae: 2.9478 - val_loss: 16.3730 - val_mae: 3.0992
# Epoch 16/60
# 19/19 [==============================] - 0s 3ms/step - loss: 16.6308 - mae: 2.8602 - val_loss: 15.8029 - val_mae: 3.0416
# Epoch 17/60
# 19/19 [==============================] - 0s 3ms/step - loss: 15.9426 - mae: 2.8071 - val_loss: 15.3196 - val_mae: 2.9800
# Epoch 18/60
# 19/19 [==============================] - 0s 3ms/step - loss: 15.2976 - mae: 2.7341 - val_loss: 14.6415 - val_mae: 2.9027
# Epoch 19/60
# 19/19 [==============================] - 0s 4ms/step - loss: 14.7956 - mae: 2.6800 - val_loss: 14.4249 - val_mae: 2.8868
# Epoch 20/60
# 19/19 [==============================] - 0s 4ms/step - loss: 14.1408 - mae: 2.6460 - val_loss: 13.8523 - val_mae: 2.8185
# Epoch 21/60
# 19/19 [==============================] - 0s 3ms/step - loss: 13.9628 - mae: 2.6214 - val_loss: 13.4000 - val_mae: 2.7586
# Epoch 22/60
# 19/19 [==============================] - 0s 3ms/step - loss: 13.2960 - mae: 2.5423 - val_loss: 13.2045 - val_mae: 2.7520
# Epoch 23/60
# 19/19 [==============================] - 0s 3ms/step - loss: 12.8896 - mae: 2.4850 - val_loss: 12.7926 - val_mae: 2.7058
# Epoch 24/60
# 19/19 [==============================] - 0s 3ms/step - loss: 12.6513 - mae: 2.4840 - val_loss: 12.2093 - val_mae: 2.6569
# Epoch 25/60
# 19/19 [==============================] - 0s 3ms/step - loss: 12.2842 - mae: 2.4611 - val_loss: 12.0627 - val_mae: 2.6365
# Epoch 26/60
# 19/19 [==============================] - 0s 3ms/step - loss: 12.1236 - mae: 2.4005 - val_loss: 11.6472 - val_mae: 2.5867
# Epoch 27/60
# 19/19 [==============================] - 0s 3ms/step - loss: 11.8713 - mae: 2.4112 - val_loss: 11.8325 - val_mae: 2.6370
# Epoch 28/60
# 19/19 [==============================] - 0s 4ms/step - loss: 11.5255 - mae: 2.3868 - val_loss: 11.0108 - val_mae: 2.5173
# Epoch 29/60
# 19/19 [==============================] - 0s 4ms/step - loss: 11.2852 - mae: 2.3475 - val_loss: 11.2368 - val_mae: 2.5649
# Epoch 30/60
# 19/19 [==============================] - 0s 4ms/step - loss: 11.1533 - mae: 2.3241 - val_loss: 11.1318 - val_mae: 2.5609
# Epoch 31/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.9662 - mae: 2.2870 - val_loss: 10.7101 - val_mae: 2.5175
# Epoch 32/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.8301 - mae: 2.3109 - val_loss: 10.5164 - val_mae: 2.5068
# Epoch 33/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.7725 - mae: 2.2741 - val_loss: 10.5972 - val_mae: 2.5198
# Epoch 34/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.4962 - mae: 2.2784 - val_loss: 10.4925 - val_mae: 2.5091
# Epoch 35/60
# 19/19 [==============================] - 0s 4ms/step - loss: 10.4014 - mae: 2.2786 - val_loss: 10.1722 - val_mae: 2.4686
# Epoch 36/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.1947 - mae: 2.2202 - val_loss: 10.1482 - val_mae: 2.4573
# Epoch 37/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.0769 - mae: 2.2209 - val_loss: 10.1612 - val_mae: 2.4781
# Epoch 38/60
# 19/19 [==============================] - 0s 3ms/step - loss: 10.0264 - mae: 2.2207 - val_loss: 9.9578 - val_mae: 2.4454
# Epoch 39/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.8587 - mae: 2.2006 - val_loss: 9.9871 - val_mae: 2.4532
# Epoch 40/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.8314 - mae: 2.1715 - val_loss: 9.6858 - val_mae: 2.4219
# Epoch 41/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.7233 - mae: 2.2106 - val_loss: 9.9827 - val_mae: 2.4649
# Epoch 42/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.5879 - mae: 2.1667 - val_loss: 9.7381 - val_mae: 2.4207
# Epoch 43/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.4692 - mae: 2.1397 - val_loss: 9.5636 - val_mae: 2.4095
# Epoch 44/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.4398 - mae: 2.1632 - val_loss: 9.4433 - val_mae: 2.3955
# Epoch 45/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.3804 - mae: 2.1402 - val_loss: 9.5763 - val_mae: 2.4048
# Epoch 46/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.3307 - mae: 2.1398 - val_loss: 9.2831 - val_mae: 2.3828
# Epoch 47/60
# 19/19 [==============================] - 0s 4ms/step - loss: 9.1899 - mae: 2.1271 - val_loss: 9.3931 - val_mae: 2.3867
# Epoch 48/60
# 19/19 [==============================] - 0s 3ms/step - loss: 9.1427 - mae: 2.1183 - val_loss: 9.4423 - val_mae: 2.3965
# Epoch 49/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.9812 - mae: 2.0880 - val_loss: 9.1740 - val_mae: 2.3628
# Epoch 50/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.9473 - mae: 2.0768 - val_loss: 9.4682 - val_mae: 2.4250
# Epoch 51/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.8661 - mae: 2.0908 - val_loss: 9.2884 - val_mae: 2.3911
# Epoch 52/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.7484 - mae: 2.0747 - val_loss: 9.1398 - val_mae: 2.3715
# Epoch 53/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.8943 - mae: 2.0852 - val_loss: 8.7326 - val_mae: 2.2998
# Epoch 54/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.7706 - mae: 2.0840 - val_loss: 9.1411 - val_mae: 2.3796
# Epoch 55/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.5797 - mae: 2.0470 - val_loss: 9.1704 - val_mae: 2.3753
# Epoch 56/60
# 19/19 [==============================] - 0s 4ms/step - loss: 8.5848 - mae: 2.0331 - val_loss: 8.9695 - val_mae: 2.3494
# Epoch 57/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.5444 - mae: 2.0583 - val_loss: 9.2812 - val_mae: 2.3914
# Epoch 58/60
# 19/19 [==============================] - 0s 4ms/step - loss: 8.3793 - mae: 2.0130 - val_loss: 8.8701 - val_mae: 2.3417
# Epoch 59/60
# 19/19 [==============================] - 0s 4ms/step - loss: 8.4276 - mae: 2.0509 - val_loss: 8.9100 - val_mae: 2.3278
# Epoch 60/60
# 19/19 [==============================] - 0s 3ms/step - loss: 8.4465 - mae: 2.0253 - val_loss: 9.1345 - val_mae: 2.3769

# %%
# 모델 학습 히스토리에서 loss, val_loss, mae, val_mae를 차트로 보여줍니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

mae = history_dict['mae']
val_mae = history_dict['val_mae']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, mae, 'b-', label='train_mae')
ax2.plot(epochs, val_mae, 'r-', label='val_mae')
ax2.set_title('Train and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 문제 1-4: 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(test_data, test_labels)

pred = model.predict(test_data)
print("실제 값: ", test_labels[10], " 예측 값: ", pred[10])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 21.6021 - mae: 2.9958
# 실제 값:  18.6  예측 값:  [16.2187]

# %% [markdown]
# ## 2. Reutuers 딥러닝 모델

# %%
# 라이브러리 불러오기
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers, initializers
from tensorflow.keras import callbacks
from tensorflow.keras import utils
from keras.datasets import reuters

# %%
# 문제 2-1: reuters 데이터셋을 로드하고, 훈련 데이터셋에서 25%를 검증 데이터셋으로 분리합니다.
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.25, random_state = 123)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇 개인지 출력합니다.
print(len(train_data))
print(len(val_data))
print(len(test_data))
print(len(set(train_labels)))
# Out:
# 6736
# 2246
# 2246
# 46

# %%
# 문제 2-2: 텍스트 데이터의 전처리를 위해서 각 데이터셋마다 원-핫 인코딩을 수행합니다.
def one_hot_encoding(data, dim=10000):
  results = np.zeros((len(data),dim))
  for i, d in enumerate(data):
    results[i, d] = 1.
  return results

x_train = one_hot_encoding(train_data)
x_val = one_hot_encoding(val_data)
x_test = one_hot_encoding(test_data)

# 레이블 데이터들은 범주형 형태로 to_categorical() 함수를 사용해 변환합니다.
y_train = utils.to_categorical(train_labels)
y_val = utils.to_categorical(val_labels)
y_test = utils.to_categorical(test_labels)

# %%
# 문제 2-3: 빠른 학습과 과대적합을 방지하기 위해 BatchNormalization과 Dropout을 적용한 딥러닝 모델을 구성합니다.
model = models.Sequential()
model.add(layers.Dense(128,kernel_initializer=initializers.HeNormal(),input_shape=(10000, )))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(128,kernel_initializer=initializers.HeNormal()))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3)) 
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='Adam',
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# %%
# 문제 2-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
check_point_cb = callbacks.ModelCheckpoint('keras_reuters_model.h5', save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=3, monitor='val_loss',
                                  restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=40,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    callbacks=[check_point_cb, early_stopping_cb])
# Out:
# Epoch 1/40
# 14/14 [==============================] - 1s 46ms/step - loss: 2.8486 - accuracy: 0.3922 - val_loss: 3.2779 - val_accuracy: 0.6069
# Epoch 2/40
# 14/14 [==============================] - 0s 16ms/step - loss: 1.5256 - accuracy: 0.6798 - val_loss: 2.8373 - val_accuracy: 0.6874
# Epoch 3/40
# 14/14 [==============================] - 0s 14ms/step - loss: 1.0952 - accuracy: 0.7559 - val_loss: 2.5724 - val_accuracy: 0.7257
# Epoch 4/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.8695 - accuracy: 0.8021 - val_loss: 2.3826 - val_accuracy: 0.7471
# Epoch 5/40
# 14/14 [==============================] - 0s 16ms/step - loss: 0.7108 - accuracy: 0.8437 - val_loss: 2.2289 - val_accuracy: 0.7431
# Epoch 6/40
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5824 - accuracy: 0.8710 - val_loss: 2.0446 - val_accuracy: 0.7418
# Epoch 7/40
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4820 - accuracy: 0.8971 - val_loss: 1.8714 - val_accuracy: 0.7444
# Epoch 8/40
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4093 - accuracy: 0.9121 - val_loss: 1.7276 - val_accuracy: 0.7489
# Epoch 9/40
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3467 - accuracy: 0.9268 - val_loss: 1.5987 - val_accuracy: 0.7462
# Epoch 10/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3009 - accuracy: 0.9365 - val_loss: 1.4837 - val_accuracy: 0.7462
# Epoch 11/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2616 - accuracy: 0.9436 - val_loss: 1.3631 - val_accuracy: 0.7520
# Epoch 12/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2419 - accuracy: 0.9473 - val_loss: 1.2864 - val_accuracy: 0.7609
# Epoch 13/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2209 - accuracy: 0.9532 - val_loss: 1.2051 - val_accuracy: 0.7671
# Epoch 14/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1973 - accuracy: 0.9549 - val_loss: 1.1504 - val_accuracy: 0.7725
# Epoch 15/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1882 - accuracy: 0.9559 - val_loss: 1.1013 - val_accuracy: 0.7774
# Epoch 16/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1677 - accuracy: 0.9598 - val_loss: 1.0482 - val_accuracy: 0.7890
# Epoch 17/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1580 - accuracy: 0.9615 - val_loss: 1.0191 - val_accuracy: 0.7890
# Epoch 18/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1485 - accuracy: 0.9632 - val_loss: 0.9957 - val_accuracy: 0.7930
# Epoch 19/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1469 - accuracy: 0.9617 - val_loss: 0.9789 - val_accuracy: 0.7939
# Epoch 20/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1411 - accuracy: 0.9608 - val_loss: 0.9760 - val_accuracy: 0.7903
# Epoch 21/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1348 - accuracy: 0.9647 - val_loss: 0.9720 - val_accuracy: 0.7925
# Epoch 22/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1281 - accuracy: 0.9667 - val_loss: 0.9715 - val_accuracy: 0.7961
# Epoch 23/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1260 - accuracy: 0.9667 - val_loss: 0.9674 - val_accuracy: 0.7970
# Epoch 24/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1248 - accuracy: 0.9669 - val_loss: 0.9714 - val_accuracy: 0.7965
# Epoch 25/40
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1194 - accuracy: 0.9679 - val_loss: 0.9871 - val_accuracy: 0.7983
# Epoch 26/40
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1120 - accuracy: 0.9672 - val_loss: 1.0005 - val_accuracy: 0.7934

# %%
# 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 문제 2-5: 테스트 데이터셋을 이용해 모델을 평가합니다.
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("테스트 데이터에서 손실 (Test Loss):", test_loss)
print("테스트 데이터에서 정확도 (Test Accuracy):", test_accuracy)
# Out:
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9641 - accuracy: 0.7992
# 테스트 데이터에서 손실 (Test Loss): 0.9640942811965942
# 테스트 데이터에서 정확도 (Test Accuracy): 0.799198567867279

# %% [markdown]
# # CIFAR10 딥러닝 모델

# %%
# 라이브러리 불러오기
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.25, random_state = 123)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (37500, 32, 32, 3) 레이블: (37500, 1)
# 검증 데이터: (12500, 32, 32, 3) 레이블: (12500, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (37500, 32, 32, 3)
# (12500, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
x_train = x_train.reshape(-1, 32 * 32 * 3)
x_val = x_val.reshape(-1, 32 * 32 * 3)
x_test = x_test.reshape(-1, 32 * 32 * 3)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (37500, 3072)
# (12500, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %%
# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = models.Sequential()

model.add(layers.Dense(2048, input_shape=(x_train.shape[1],)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))

model.add(layers.Dense(1024))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))

model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='Adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 2048)              6293504
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_2 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 8,935,946
# Trainable params: 8,928,778
# Non-trainable params: 7,168
# _________________________________________________________________

# %%
utils.plot_model(model, show_shapes=True)

# %%
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
check_point_cb = callbacks.ModelCheckpoint('keras_cifar10_model.h5', save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=10, monitor='val_loss',
                                  restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=60,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    callbacks=[check_point_cb, early_stopping_cb])
# Out:
# Epoch 1/60
# 74/74 [==============================] - 2s 20ms/step - loss: 1.9002 - accuracy: 0.3394 - val_loss: 2.2939 - val_accuracy: 0.2754
# Epoch 2/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.6049 - accuracy: 0.4293 - val_loss: 2.0733 - val_accuracy: 0.2750
# Epoch 3/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.4755 - accuracy: 0.4715 - val_loss: 1.7395 - val_accuracy: 0.3797
# Epoch 4/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.3881 - accuracy: 0.5055 - val_loss: 1.8970 - val_accuracy: 0.3465
# Epoch 5/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.3152 - accuracy: 0.5308 - val_loss: 1.7110 - val_accuracy: 0.4040
# Epoch 6/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.2590 - accuracy: 0.5501 - val_loss: 1.7309 - val_accuracy: 0.3822
# Epoch 7/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.1998 - accuracy: 0.5714 - val_loss: 1.7813 - val_accuracy: 0.3710
# Epoch 8/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.1664 - accuracy: 0.5843 - val_loss: 1.8482 - val_accuracy: 0.3538
# Epoch 9/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.1206 - accuracy: 0.6002 - val_loss: 1.8600 - val_accuracy: 0.3509
# Epoch 10/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.0844 - accuracy: 0.6123 - val_loss: 1.7841 - val_accuracy: 0.3851
# Epoch 11/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.0352 - accuracy: 0.6283 - val_loss: 1.7316 - val_accuracy: 0.3849
# Epoch 12/60
# 74/74 [==============================] - 1s 12ms/step - loss: 1.0007 - accuracy: 0.6426 - val_loss: 1.7032 - val_accuracy: 0.4146
# Epoch 13/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.9584 - accuracy: 0.6563 - val_loss: 1.6208 - val_accuracy: 0.4266
# Epoch 14/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.9233 - accuracy: 0.6693 - val_loss: 1.8175 - val_accuracy: 0.3922
# Epoch 15/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.8982 - accuracy: 0.6765 - val_loss: 1.8402 - val_accuracy: 0.3801
# Epoch 16/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.8553 - accuracy: 0.6945 - val_loss: 1.7656 - val_accuracy: 0.4071
# Epoch 17/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.8230 - accuracy: 0.7061 - val_loss: 1.5103 - val_accuracy: 0.4664
# Epoch 18/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.7934 - accuracy: 0.7160 - val_loss: 1.7174 - val_accuracy: 0.4399
# Epoch 19/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.7638 - accuracy: 0.7275 - val_loss: 1.6694 - val_accuracy: 0.4443
# Epoch 20/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.7330 - accuracy: 0.7349 - val_loss: 1.6369 - val_accuracy: 0.4448
# Epoch 21/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.6992 - accuracy: 0.7485 - val_loss: 1.6959 - val_accuracy: 0.4544
# Epoch 22/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.6690 - accuracy: 0.7597 - val_loss: 1.7399 - val_accuracy: 0.4286
# Epoch 23/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.6335 - accuracy: 0.7729 - val_loss: 2.1198 - val_accuracy: 0.4146
# Epoch 24/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.6133 - accuracy: 0.7782 - val_loss: 1.7886 - val_accuracy: 0.4524
# Epoch 25/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.5790 - accuracy: 0.7926 - val_loss: 1.7090 - val_accuracy: 0.4537
# Epoch 26/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.5685 - accuracy: 0.7980 - val_loss: 2.0160 - val_accuracy: 0.4104
# Epoch 27/60
# 74/74 [==============================] - 1s 12ms/step - loss: 0.5378 - accuracy: 0.8075 - val_loss: 2.2333 - val_accuracy: 0.3764

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5190 - accuracy: 0.4638
# [1.5189721584320068, 0.46380001306533813]
